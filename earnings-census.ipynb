# %%
import pandas as pd
import numpy as np

# we are here to use the current population survey to get data on wages, ages could also be found here.

# impumspy client library
from ipumspy import IpumsApiClient, CpsExtract
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       2 import numpy as np
#       4 # we are here to use the current population survey to get data on wages, ages could also be found here.
#       5
#       6 # impumspy client library
# ----> 7 from ipumspy import IpumsApiClient, CpsExtract
#
# ImportError: cannot import name 'CpsExtract' from 'ipumspy' (/Users/kevinphan981/Programming/occupational-licensing-study/.venv/lib/python3.13/site-packages/ipumspy/__init__.py)
